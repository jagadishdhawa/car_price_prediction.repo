# %% [markdown]
# ### Importing required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Load the Dataset

# %%
df = pd.read_csv('CAR DETAILS.csv')

# %% [markdown]
# ### Display top 5 rows

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
df["brand"] = df["name"].agg(str.split).str[0]
print(df["brand"].value_counts())
# Out:
# brand
# Maruti           1280
# Hyundai           821
# Mahindra          365
# Tata              361
# Honda             252
# Ford              238
# Toyota            206
# Chevrolet         188
# Renault           146
# Volkswagen        107
# Skoda              68
# Nissan             64
# Audi               60
# BMW                39
# Fiat               37
# Datsun             37
# Mercedes-Benz      35
# Jaguar              6
# Mitsubishi          6
# Land                5
# Volvo               4
# Ambassador          4
# Jeep                3
# MG                  2
# OpelCorsa           2
# Daewoo              1
# Force               1
# Isuzu               1
# Kia                 1
# Name: count, dtype: int64

# %% [markdown]
# ### Checking the shape

# %%
df.shape
# Out:
# (4340, 9)

# %% [markdown]
# ### The dataset contains 4340 rows and 8 columns of customer information.

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'brand'],
#       dtype='object')

# %% [markdown]
# ### checking the datatype

# %%
df.dtypes
# Out:
# name             object
# year              int64
# selling_price     int64
# km_driven         int64
# fuel             object
# seller_type      object
# transmission     object
# owner            object
# brand            object
# dtype: object

# %% [markdown]
# ### Changing the datatype of date column

# %%
df['year'] = pd.to_datetime(df['year'], format='%Y').dt.year

df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner    brand
# 0  Individual       Manual   First Owner   Maruti
# 1  Individual       Manual   First Owner   Maruti
# 2  Individual       Manual   First Owner  Hyundai
# 3  Individual       Manual   First Owner   Datsun
# 4  Individual       Manual  Second Owner    Honda

# %% [markdown]
# ### Handling Duplicates

# %%
df.duplicated().sum()
# Out:
# 763

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (3577, 9)

# %% [markdown]
# ### EDA-

# %% [markdown]
# ### Handling null values

# %%
nv = df.isnull().sum()
nv = nv[nv>0]
nv
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ### No missing values are observed in the dataset

# %%
# Generate summary statistics for numerical columns
print(df.describe())
# Out:
#               year  selling_price      km_driven
# count  3577.000000   3.577000e+03    3577.000000
# mean   2012.962538   4.739125e+05   69250.545709
# std       4.251759   5.093018e+05   47579.940016
# min    1992.000000   2.000000e+04       1.000000
# 25%    2010.000000   2.000000e+05   36000.000000
# 50%    2013.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %%
# Bar plot for the fuel column
plt.figure(figsize=(8, 6))
sns.countplot(x='fuel', data=df)
plt.xlabel('Fuel Type')
plt.ylabel('Count')
plt.title('Distribution of Fuel Types')
plt.show()

# %%
# Histogram for the 'selling_price' column
plt.figure(figsize=(8, 6))
plt.hist(df['selling_price'], bins=30, edgecolor='black')
plt.xlabel('Selling Price')
plt.ylabel('Frequency')
plt.title('Histogram of Selling Price')
plt.show()

# %%
# Box plot to identify potential outliers in 'selling_price'
plt.figure(figsize=(8, 6))
sns.boxplot(df['selling_price'])
plt.xlabel('Selling Price')
plt.title('Box Plot: Selling Price')
plt.show()

# %%
sorted(df['selling_price'],reverse=True)
# Out:
# [8900000,
#  8150000,
#  5500000,
#  4950000,
#  4800000,
#  4800000,
#  4700000,
#  4500000,
#  4500000,
#  4400000,
#  4200000,
#  4000000,
#  4000000,
#  4000000,
#  3899000,
#  3800000,
#  3500000,
#  3500000,
#  3256000,
#  3200000,
#  3200000,
#  3200000,
#  3100000,
#  3100000,
#  3050000,
#  2900000,
#  2800000,
#  2800000,
#  2800000,
#  2800000,
#  2750000,
#  2750000,
#  2700000,
#  2700000,
#  2700000,
#  2675000,
#  2675000,
#  2650000,
#  2600000,
#  2600000,
#  2595000,
#  2575000,
#  2550000,
#  2500000,
#  2500000,
#  2500000,
#  2500000,
#  2490000,
#  2400000,
#  2349000,
#  2300000,
#  2300000,
#  2200000,
#  2150000,
#  2100000,
#  2050000,
#  2000000,
#  2000000,
#  2000000,
#  2000000,
#  1975000,
#  1964999,
#  1950000,
#  1900000,
#  1900000,
#  1900000,
#  1900000,
#  1860000,
#  1850000,
#  1850000,
#  1825000,
#  1800000,
#  1800000,
#  1800000,
#  1800000,
#  1800000,
#  1800000,
#  1800000,
#  1770000,
#  1750000,
#  1750000,
#  1750000,
#  1735000,
#  1725000,
#  1700000,
#  1700000,
#  1700000,
#  1700000,
#  1700000,
#  1700000,
#  1680000,
#  1650000,
#  1650000,
#  1600000,
#  1600000,
#  1600000,
#  1580000,
#  1575000,
#  1550000,
#  1549000,
#  1500000,
#  1500000,
#  1500000,
#  1500000,
#  1500000,
#  1500000,
#  1500000,
#  1500000,
#  1490000,
#  1490000,
#  1490000,
#  1485000,
#  1475000,
#  1470000,
#  1451000,
#  1450000,
#  1425000,
#  1400000,
#  1400000,
#  1400000,
#  1400000,
#  1400000,
#  1400000,
#  1400000,
#  1400000,
#  1400000,
#  1380000,
#  1375000,
#  1375000,
#  1350000,
#  1350000,
#  1350000,
#  1350000,
#  1350000,
#  1350000,
#  1350000,
#  1334000,
#  1331000,
#  1330000,
#  1300000,
#  1300000,
#  1300000,
#  1300000,
#  1300000,
#  1300000,
#  1300000,
#  1300000,
#  1300000,
#  1295000,
#  1295000,
#  1290000,
#  1280000,
#  1260000,
#  1250000,
#  1250000,
#  1250000,
#  1250000,
#  1250000,
#  1250000,
#  1250000,
#  1250000,
#  1250000,
#  1250000,
#  1250000,
#  1249000,
#  1249000,
#  1240000,
#  1230000,
#  1225000,
#  1225000,
#  1200000,
#  1200000,
#  1200000,
#  1200000,
#  1200000,
#  1200000,
#  1200000,
#  1200000,
#  1200000,
#  1200000,
#  1200000,
#  1200000,
#  1200000,
#  1200000,
#  1200000,
#  1199000,
#  1195000,
#  1190000,
#  1189000,
#  1165000,
#  1151000,
#  1150000,
#  1150000,
#  1150000,
#  1150000,
#  1150000,
#  1150000,
#  1150000,
#  1150000,
#  1150000,
#  1150000,
#  1150000,
#  1140000,
#  1125000,
#  1119000,
#  1100000,
#  1100000,
#  1100000,
#  1100000,
#  1100000,
#  1100000,
#  1100000,
#  1100000,
#  1100000,
#  1100000,
#  1100000,
#  1100000,
#  1100000,
#  1100000,
#  1100000,
#  1090000,
#  1085000,
#  1075000,
#  1068000,
#  1050000,
#  1050000,
#  1050000,
#  1050000,
#  1050000,
#  1050000,
#  1050000,
#  1050000,
#  1050000,
#  1044999,
#  1044999,
#  1040000,
#  1035000,
#  1030000,
#  1030000,
#  1025000,
#  1025000,
#  1025000,
#  1025000,
#  1025000,
#  1015000,
#  1010000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  999000,
#  990000,
#  980000,
#  980000,
#  975000,
#  975000,
#  969999,
#  969999,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  940000,
#  940000,
#  940000,
#  940000,
#  940000,
#  936999,
#  930000,
#  930000,
#  930000,
#  927999,
#  925000,
#  925000,
#  925000,
#  925000,
#  925000,
#  925000,
#  925000,
#  925000,
#  919999,
#  919999,
#  910000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  894999,
#  894999,
#  890000,
#  890000,
#  890000,
#  890000,
#  890000,
#  890000,
#  890000,
#  880000,
#  875000,
#  875000,
#  875000,
#  875000,
#  869999,
#  869999,
#  865000,
#  861999,
#  860000,
#  860000,
#  860000,
#  852000,
#  851000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  844999,
#  844999,
#  841000,
#  840000,
#  840000,
#  840000,
#  836000,
#  836000,
#  835000,
#  830000,
#  830000,
#  830000,
#  830000,
#  828999,
#  825000,
#  825000,
#  825000,
#  825000,
#  825000,
#  825000,
#  825000,
#  825000,
#  821000,
#  819999,
#  819999,
#  819999,
#  819999,
#  815000,
#  811999,
#  810000,
#  802000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  799000,
#  795000,
#  795000,
#  790000,
#  790000,
#  790000,
#  790000,
#  790000,
#  790000,
#  790000,
#  785000,
#  785000,
#  784000,
#  784000,
#  782000,
#  782000,
#  780000,
#  780000,
#  780000,
#  780000,
#  780000,
#  780000,
#  780000,
#  780000,
#  775000,
#  775000,
#  775000,
#  774000,
#  770000,
#  770000,
#  765000,
#  763000,
#  760000,
#  760000,
#  760000,
#  760000,
#  760000,
#  755000,
#  751000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  749000,
#  746000,
#  744000,
#  740000,
#  740000,
#  740000,
#  738000,
#  735000,
#  730000,
#  730000,
#  730000,
#  725000,
#  725000,
#  725000,
#  725000,
#  725000,
#  725000,
#  725000,
#  725000,
#  725000,
#  725000,
#  725000,
#  725000,
#  725000,
#  724000,
#  721000,
#  720000,
#  720000,
#  720000,
#  720000,
#  720000,
#  716000,
#  715000,
#  715000,
#  715000,
#  715000,
#  711000,
#  711000,
#  710000,
#  710000,
#  710000,
#  707000,
#  701000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  699000,
#  699000,
#  699000,
#  696000,
#  695000,
#  690000,
#  690000,
#  690000,
#  690000,
#  690000,
#  690000,
#  690000,
#  690000,
#  690000,
#  685000,
#  685000,
#  685000,
#  680000,
#  680000,
#  680000,
#  680000,
#  680000,
#  680000,
#  680000,
#  675000,
#  675000,
#  675000,
#  675000,
#  675000,
#  675000,
#  675000,
#  675000,
#  675000,
#  675000,
#  675000,
#  675000,
#  670000,
#  670000,
#  670000,
#  670000,
#  665000,
#  665000,
#  665000,
#  665000,
#  665000,
#  665000,
#  660000,
#  660000,
#  660000,
#  660000,
#  660000,
#  660000,
#  655000,
#  655000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  641000,
#  640000,
#  640000,
#  640000,
#  640000,
#  640000,
#  640000,
#  640000,
#  640000,
#  640000,
#  639000,
#  635000,
#  635000,
#  635000,
#  630000,
#  630000,
#  630000,
#  630000,
#  630000,
#  630000,
#  630000,
#  630000,
#  628000,
#  625000,
#  625000,
#  625000,
#  625000,
#  625000,
#  625000,
#  625000,
#  625000,
#  625000,
#  625000,
#  624000,
#  620000,
#  620000,
#  620000,
#  620000,
#  620000,
#  620000,
#  620000,
#  620000,
#  620000,
#  619000,
#  619000,
#  615000,
#  615000,
#  615000,
#  615000,
#  614000,
#  612000,
#  611000,
#  610000,
#  610000,
#  610000,
#  610000,
#  610000,
#  610000,
#  610000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  599000,
#  599000,
#  599000,
#  596000,
#  595000,
#  595000,
#  595000,
#  595000,
#  590000,
#  590000,
#  590000,
#  590000,
#  587000,
#  585000,
#  585000,
#  585000,
#  585000,
#  585000,
#  585000,
#  580000,
#  580000,
#  580000,
#  580000,
#  580000,
#  580000,
#  580000,
#  580000,
#  580000,
#  580000,
#  580000,
#  580000,
#  575000,
#  575000,
#  575000,
#  575000,
#  575000,
#  575000,
#  575000,
#  575000,
#  575000,
#  575000,
#  575000,
#  575000,
#  570000,
#  570000,
#  570000,
#  570000,
#  570000,
#  570000,
#  565000,
#  565000,
#  565000,
#  565000,
#  560000,
#  560000,
#  556000,
#  555000,
#  555000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  ...]

# %%
df = df[~(df['selling_price']>=5500000) & (df['selling_price']<=8900000)]

# %%
# Scatter plot for 'km_driven' vs. 'selling_price'
plt.figure(figsize=(8, 6))
plt.scatter(df['km_driven'], df['selling_price'], alpha=0.5)
plt.xlabel('Kilometers Driven')
plt.ylabel('Selling Price')
plt.title('Scatter Plot: Kilometers Driven vs. Selling Price')
plt.grid(True)
plt.show()

# %%
sorted(df['km_driven'],reverse=True)
# Out:
# [806599,
#  560000,
#  400000,
#  350000,
#  350000,
#  347089,
#  312000,
#  300000,
#  300000,
#  300000,
#  300000,
#  296823,
#  295000,
#  280000,
#  270000,
#  267000,
#  260000,
#  256000,
#  250000,
#  250000,
#  250000,
#  250000,
#  250000,
#  245244,
#  244000,
#  240000,
#  238000,
#  235000,
#  235000,
#  234000,
#  230000,
#  230000,
#  230000,
#  230000,
#  224642,
#  223660,
#  223000,
#  223000,
#  222435,
#  222252,
#  221000,
#  220000,
#  220000,
#  220000,
#  218000,
#  217871,
#  213000,
#  212814,
#  210000,
#  210000,
#  206500,
#  205000,
#  205000,
#  200000,
#  200000,
#  200000,
#  200000,
#  200000,
#  200000,
#  200000,
#  200000,
#  200000,
#  200000,
#  200000,
#  200000,
#  200000,
#  200000,
#  200000,
#  197000,
#  195000,
#  195000,
#  195000,
#  192000,
#  190621,
#  190000,
#  190000,
#  190000,
#  190000,
#  190000,
#  190000,
#  186000,
#  186000,
#  186000,
#  185000,
#  185000,
#  185000,
#  182000,
#  181000,
#  180000,
#  180000,
#  180000,
#  180000,
#  180000,
#  180000,
#  180000,
#  180000,
#  180000,
#  178000,
#  175900,
#  175000,
#  175000,
#  175000,
#  175000,
#  175000,
#  173000,
#  172000,
#  170000,
#  170000,
#  170000,
#  170000,
#  170000,
#  170000,
#  170000,
#  170000,
#  170000,
#  170000,
#  170000,
#  170000,
#  170000,
#  168000,
#  167870,
#  167223,
#  166000,
#  165000,
#  164000,
#  163000,
#  163000,
#  162000,
#  161327,
#  160254,
#  160000,
#  160000,
#  160000,
#  160000,
#  160000,
#  160000,
#  160000,
#  160000,
#  160000,
#  160000,
#  160000,
#  160000,
#  159000,
#  158000,
#  157000,
#  157000,
#  156040,
#  156000,
#  156000,
#  155836,
#  155500,
#  155201,
#  155000,
#  155000,
#  155000,
#  154000,
#  154000,
#  152000,
#  151624,
#  151000,
#  150000,
#  150000,
#  150000,
#  150000,
#  150000,
#  150000,
#  150000,
#  150000,
#  150000,
#  150000,
#  150000,
#  150000,
#  150000,
#  150000,
#  150000,
#  150000,
#  150000,
#  150000,
#  149674,
#  149500,
#  149000,
#  149000,
#  148620,
#  146000,
#  146000,
#  146000,
#  146000,
#  145000,
#  145000,
#  145000,
#  145000,
#  144000,
#  144000,
#  143000,
#  142000,
#  141440,
#  141000,
#  140730,
#  140300,
#  140000,
#  140000,
#  140000,
#  140000,
#  140000,
#  140000,
#  140000,
#  140000,
#  140000,
#  140000,
#  140000,
#  140000,
#  140000,
#  140000,
#  140000,
#  140000,
#  140000,
#  140000,
#  140000,
#  139000,
#  138925,
#  138000,
#  137250,
#  136906,
#  136000,
#  135200,
#  135000,
#  135000,
#  135000,
#  135000,
#  135000,
#  135000,
#  135000,
#  135000,
#  135000,
#  135000,
#  134444,
#  134000,
#  133564,
#  133000,
#  133000,
#  132343,
#  132000,
#  131365,
#  130400,
#  130000,
#  130000,
#  130000,
#  130000,
#  130000,
#  130000,
#  130000,
#  130000,
#  130000,
#  130000,
#  130000,
#  130000,
#  130000,
#  130000,
#  130000,
#  130000,
#  129627,
#  129000,
#  128000,
#  128000,
#  127884,
#  127643,
#  127500,
#  126000,
#  126000,
#  126000,
#  125531,
#  125000,
#  125000,
#  125000,
#  125000,
#  125000,
#  125000,
#  125000,
#  125000,
#  124439,
#  124000,
#  124000,
#  124000,
#  123084,
#  121764,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  120000,
#  119000,
#  119000,
#  118700,
#  118400,
#  118000,
#  117780,
#  117000,
#  116000,
#  116000,
#  115992,
#  115962,
#  115000,
#  115000,
#  115000,
#  115000,
#  115000,
#  114000,
#  113600,
#  112880,
#  112198,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  110000,
#  109052,
#  109000,
#  109000,
#  108731,
#  108000,
#  107500,
#  107143,
#  107000,
#  106000,
#  106000,
#  106000,
#  105700,
#  105546,
#  105429,
#  105000,
#  105000,
#  105000,
#  105000,
#  105000,
#  105000,
#  104000,
#  104000,
#  103921,
#  102989,
#  102354,
#  102307,
#  102000,
#  102000,
#  102000,
#  102000,
#  101849,
#  101504,
#  101159,
#  101100,
#  101000,
#  101000,
#  100005,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  100000,
#  99700,
#  99117,
#  99000,
#  99000,
#  99000,
#  98900,
#  98600,
#  98000,
#  98000,
#  98000,
#  98000,
#  98000,
#  97700,
#  97248,
#  97000,
#  97000,
#  97000,
#  97000,
#  97000,
#  97000,
#  97000,
#  97000,
#  97000,
#  97000,
#  97000,
#  96987,
#  96000,
#  96000,
#  96000,
#  96000,
#  95851,
#  95149,
#  95000,
#  95000,
#  95000,
#  95000,
#  94000,
#  93900,
#  93415,
#  93283,
#  93000,
#  93000,
#  92686,
#  92645,
#  92621,
#  92198,
#  92000,
#  92000,
#  91505,
#  91365,
#  91245,
#  91195,
#  91086,
#  90658,
#  90246,
#  90165,
#  90010,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  90000,
#  ...]

# %%
df = df[~(df['km_driven']>=400000) & (df['km_driven']<=806599)]

# %%
# Box plot for 'fuel' vs. 'selling_price'
plt.figure(figsize=(8, 6))
sns.boxplot(x='fuel', y='selling_price', data=df)
plt.xlabel('Fuel Type')
plt.ylabel('Selling Price')
plt.title('Box Plot: Fuel Type vs. Selling Price')
plt.show()

# %%
print(df.info())
cars_train = df[["year", "km_driven", "fuel", "seller_type", "transmission", "brand", "owner"]]
print(df["brand"].head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3571 entries, 0 to 4339
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           3571 non-null   object
#  1   year           3571 non-null   int32
#  2   selling_price  3571 non-null   int64
#  3   km_driven      3571 non-null   int64
#  4   fuel           3571 non-null   object
#  5   seller_type    3571 non-null   object
#  6   transmission   3571 non-null   object
#  7   owner          3571 non-null   object
#  8   brand          3571 non-null   object
# dtypes: int32(1), int64(2), object(6)
# memory usage: 265.0+ KB
# None
# 0     Maruti
# 1     Maruti
# 2    Hyundai
# 3     Datsun
# 4      Honda
# Name: brand, dtype: object

# %%
from sklearn import preprocessing

# %%
print(cars_train["seller_type"].unique())
le_seller = preprocessing.LabelEncoder()
le_seller.fit(cars_train["seller_type"])
cars_train["seller_type"] = le_seller.transform(cars_train["seller_type"])
print(cars_train["seller_type"].head())
# Out:
# ['Individual' 'Dealer' 'Trustmark Dealer']
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: seller_type, dtype: int32
# C:\Users\mriganka\AppData\Local\Temp\ipykernel_6072\83033486.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cars_train["seller_type"] = le_seller.transform(cars_train["seller_type"])

# %%
print(cars_train["transmission"].unique())
le_trans = preprocessing.LabelEncoder()
le_trans.fit(cars_train["transmission"])
cars_train["transmission"] = le_trans.transform(cars_train["transmission"])
print(cars_train["transmission"].head())
# Out:
# ['Manual' 'Automatic']
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: transmission, dtype: int32
# C:\Users\mriganka\AppData\Local\Temp\ipykernel_6072\1819588227.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cars_train["transmission"] = le_trans.transform(cars_train["transmission"])

# %%
print(cars_train["fuel"].unique())
le_fuel = preprocessing.LabelEncoder()
le_fuel.fit(cars_train["fuel"])
cars_train["fuel"] = le_fuel.transform(cars_train["fuel"])
print(cars_train["fuel"].head())
# Out:
# ['Petrol' 'Diesel' 'CNG' 'LPG' 'Electric']
# 0    4
# 1    4
# 2    1
# 3    4
# 4    1
# Name: fuel, dtype: int32
# C:\Users\mriganka\AppData\Local\Temp\ipykernel_6072\873178307.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cars_train["fuel"] = le_fuel.transform(cars_train["fuel"])

# %%
print(cars_train["owner"].unique())
le_owner = preprocessing.LabelEncoder()
le_owner.fit(cars_train["owner"])
cars_train["owner"] = le_owner.transform(cars_train["owner"])
print(cars_train["owner"].head())
# Out:
# ['First Owner' 'Second Owner' 'Fourth & Above Owner' 'Third Owner'
#  'Test Drive Car']
# 0    0
# 1    0
# 2    0
# 3    0
# 4    2
# Name: owner, dtype: int32
# C:\Users\mriganka\AppData\Local\Temp\ipykernel_6072\1802526469.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cars_train["owner"] = le_owner.transform(cars_train["owner"])

# %%
le_brand = preprocessing.LabelEncoder()
le_brand.fit(cars_train["brand"])
cars_train["brand"] = le_brand.transform(cars_train["brand"])
print(cars_train["brand"].head())
# Out:
# 0    18
# 1    18
# 2    10
# 3     5
# 4     9
# Name: brand, dtype: int32
# C:\Users\mriganka\AppData\Local\Temp\ipykernel_6072\2382215879.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cars_train["brand"] = le_brand.transform(cars_train["brand"])

# %%
y = df["selling_price"]
print(y.shape)
x = cars_train
print(x.shape)
# Out:
# (3571,)
# (3571, 7)

# %%
from sklearn.model_selection import KFold
kf = KFold(n_splits=3,shuffle=True)
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %% [markdown]
# ### Data Pre-Processing:

# %% [markdown]
# Prepare the Data for Machine Learning Modeling

# %% [markdown]
#  Apply Various Machine Learning Techniques

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor


# Create and train different models
model1 = LinearRegression()
model2 = RandomForestRegressor()
model3 = Ridge(alpha=0.4)
model4 = Lasso(alpha = 15.7)


# Fit the models on the training data
model1.fit(x_train, y_train)
model2.fit(x_train, y_train)
model3.fit(x_train, y_train)
model4.fit(x_train, y_train)
# Out:
# Lasso(alpha=15.7)

# %% [markdown]
# Creating Functions to compute Regression Evaluation Metrics

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

def reg_eval_metrics(ytest,ypred):
  mae = mean_absolute_error(ytest,ypred)
  mse = mean_squared_error(ytest,ypred)
  rmse = np.sqrt(mse)
  r2 = r2_score(ytest,ypred)
  print('MAE',mae)
  print('MSE',mse)
  print('RMSE',rmse)
  print('R2 Score',r2)

def mscore(model):
  print('Training Score',model.score(x_train,y_train))  # Training Score
  print('Testing Score',model.score(x_test,y_test))     #Testing R2 score

# %% [markdown]
# ### Predictions

# %% [markdown]
# LinearRegression

# %%
mscore(model1)
# Out:
# Training Score 0.465058020241357
# Testing Score 0.4825183485648279

# %%
ypred_model1 = model1.predict(x_test)

# %%
reg_eval_metrics(y_test,ypred_model1)
# Out:
# MAE 206753.8690289048
# MSE 123641798599.34065
# RMSE 351627.3575809207
# R2 Score 0.4825183485648279

# %% [markdown]
# RandomForestRegressor

# %%
mscore(model2)
# Out:
# Training Score 0.9370797548758852
# Testing Score 0.7623986188746241

# %%
ypred_model2 = model2.predict(x_test)

# %%
reg_eval_metrics(y_test,ypred_model2)
# Out:
# MAE 146532.11655053802
# MSE 56770055576.95448
# RMSE 238264.67547027295
# R2 Score 0.7623986188746241

# %% [markdown]
# Ridge

# %%
mscore(model3)
# Out:
# Training Score 0.4650573918027373
# Testing Score 0.4824942891912831

# %%
ypred_model3 = model3.predict(x_test)

# %%
reg_eval_metrics(y_test,ypred_model3)
# Out:
# MAE 206734.97771479658
# MSE 123647547101.16673
# RMSE 351635.53162495786
# R2 Score 0.4824942891912831

# %% [markdown]
# Lasso

# %%
mscore(model4)
# Out:
# Training Score 0.465057999335455
# Testing Score 0.48251170636493723

# %%
ypred_model4 = model4.predict(x_test)

# %%
reg_eval_metrics(y_test,ypred_model4)
# Out:
# MAE 206749.7873024982
# MSE 123643385618.97481
# RMSE 351629.6142519495
# R2 Score 0.48251170636493723

# %%
import joblib

car_price_prediction = 'model2.pkl'
joblib.dump(model2, car_price_prediction)
# Out:
# ['model2.pkl']

# %%
# Load the saved model
car_price_prediction = 'model2.pkl'
loaded_model = joblib.load(car_price_prediction)

# Create a new dataset by randomly selecting 20 data points from the original dataset
new_dataset = df.sample(n=20, random_state=42)

# Assuming 'X_new' contains the features of the new dataset
x_new = new_dataset[["year", "km_driven", "fuel", "seller_type", "transmission", "brand", "owner"]]

# Apply the loaded model to the new dataset
predictions = loaded_model.predict(x_new)

# Print the predictions
print(predictions)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6072\1100104919.py in ?()
#       8 # Assuming 'X_new' contains the features of the new dataset
#       9 x_new = new_dataset[["year", "km_driven", "fuel", "seller_type", "transmission", "brand", "owner"]]
#      10
#      11 # Apply the loaded model to the new dataset
# ---> 12 predictions = loaded_model.predict(x_new)
#      13
#      14 # Print the predictions
#      15 print(predictions)
#
# c:\Users\mriganka\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\ensemble\_forest.py in ?(self, X)
#     980             The predicted values.
#     981         """
#     982         check_is_fitted(self)
#     983         # Check data
# --> 984         X = self._validate_X_predict(X)
#     985
#     986         # Assign chunk of trees to jobs
#     987         n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# c:\Users\mriganka\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\ensemble\_forest.py in ?(self, X)
#     595     def _validate_X_predict(self, X):
#     596         """
#     597         Validate X whenever one tries to predict, apply, predict_proba."""
#     598         check_is_fitted(self)
# --> 599         X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#     600         if issparse(X) and (X.indices.dtype != np.intc or X.indptr.dtype != np.intc):
#     601             raise ValueError("No support for np.int64 index based sparse matrices")
#     602         return X
#
# c:\Users\mriganka\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py in ?(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     600                 out = y
#     601             else:
#     602                 out = X, y
#     603         elif not no_val_X and no_val_y:
# --> 604             out = check_array(X, input_name="X", **check_params)
#     605         elif no_val_X and not no_val_y:
#     606             out = _check_y(y, **check_params)
#     607         else:
#
# c:\Users\mriganka\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     914                         )
#     915                     array = xp.astype(array, dtype, copy=False)
#     916                 else:
#     917                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# --> 918             except ComplexWarning as complex_warning:
#     919                 raise ValueError(
#     920                     "Complex data not supported\n{}\n".format(array)
#     921                 ) from complex_warning
#
# c:\Users\mriganka\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp)
#     376         # Use NumPy API to support order
#     377         if copy is True:
#     378             array = numpy.array(array, order=order, dtype=dtype)
#     379         else:
# --> 380             array = numpy.asarray(array, order=order, dtype=dtype)
#     381
#     382         # At this point array is a NumPy ndarray. We convert it to an array
#     383         # container that is consistent with the input's namespace.
#
# c:\Users\mriganka\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, dtype)
#    1996     def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#    1997         values = self._values
# -> 1998         arr = np.asarray(values, dtype=dtype)
#    1999         if (
#    2000             astype_is_view(values.dtype, arr.dtype)
#    2001             and using_copy_on_write()
#
# ValueError: could not convert string to float: 'Petrol'
